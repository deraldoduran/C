# %% [markdown]
# <a href="https://colab.research.google.com/github/deraldoduran/C/blob/master/exercicioarvorededecisao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
caracteristicas=[[140,1],[130,1],[150,0],[170,0],[180,2],[175,2]]

# %%
rotulos=['maca','maca','laranja','laranja','pera','pera']

# %%
X=pd.DataFrame(caracteristicas,columns=(['PESO','TEXTURA']))

# %%
y = pd.DataFrame(rotulos, columns=['ROTULO'])

# %%
final = pd.concat([X,y], axis=1)
final.sort_values(by='PESO')
# Out:
#    PESO  TEXTURA   ROTULO
# 1   130        1     maca
# 0   140        1     maca
# 2   150        0  laranja
# 3   170        0  laranja
# 5   175        2     pera
# 4   180        2     pera

# %%
clf = DecisionTreeClassifier(random_state=42)
clf = clf.fit(caracteristicas, rotulos)

# %%
clf.predict([[175,2]])
# Out:
# array(['pera'], dtype='<U7')

# %%
sklearn.__version__
# Out:
# '0.21.3'

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
plt.figure(figsize=[10,10])
plot_tree(clf, filled=True, feature_names = ['peso', 'textura'], class_names=['maça','laranja','pera']);

# %%
clf.feature_importances_
# Out:
# array([0.5, 0.5])
